# %%
def predict_score(att=None,
                  comp=None,
                  pass_yds=None,
                  pass_td=None,
                  _int=None,
                  field_2pt_pass=None,
                  rush_yds=None,
                  rush_td=None):
    """ Predictor for Score from model/5b5a16ba92fb564ba1000129

        Predictive model by BigML - Machine Learning Made Easy
    """
    if (pass_td is None):
        return 16.05226
    if (pass_td > 1):
        if (pass_td > 2):
            if (pass_td > 3):
                if (pass_td > 4):
                    if (pass_td > 5):
                        if (pass_yds is None):
                            return 53.33333
                        if (pass_yds > 382):
                            return 58.25
                        if (pass_yds <= 382):
                            return 49.4
                    if (pass_td <= 5):
                        if (att is None):
                            return 43.16667
                        if (att > 44):
                            return 49.5
                        if (att <= 44):
                            if (field_2pt_pass is None):
                                return 42.59091
                            if (field_2pt_pass > 0):
                                if (pass_yds is None):
                                    return 46.66667
                                if (pass_yds > 442):
                                    return 50
                                if (pass_yds <= 442):
                                    return 45
                            if (field_2pt_pass <= 0):
                                if (pass_yds is None):
                                    return 41.94737
                                if (pass_yds > 259):
                                    return 42.66667
                                if (pass_yds <= 259):
                                    return 39.25
                if (pass_td <= 4):
                    if (pass_yds is None):
                        return 36.59574
                    if (pass_yds > 306):
                        if (rush_td is None):
                            return 38.41026
                        if (rush_td > 0):
                            return 43.83333
                        if (rush_td <= 0):
                            if (pass_yds > 362):
                                if (rush_yds is None):
                                    return 39.09091
                                if (rush_yds > 12):
                                    if (_int is None):
                                        return 40.85714
                                    if (_int > 1):
                                        return 38
                                    if (_int <= 1):
                                        return 41.63636
                                if (rush_yds <= 12):
                                    if (_int is None):
                                        return 38.26667
                                    if (_int > 0):
                                        if (pass_yds > 457):
                                            return 39.5
                                        if (pass_yds <= 457):
                                            return 36.36364
                                    if (_int <= 0):
                                        if (pass_yds > 427):
                                            return 42
                                        if (pass_yds <= 427):
                                            return 39
                            if (pass_yds <= 362):
                                if (_int is None):
                                    return 36.17857
                                if (_int > 2):
                                    return 31.33333
                                if (_int <= 2):
                                    if (rush_yds is None):
                                        return 36.76
                                    if (rush_yds > 28):
                                        return 40
                                    if (rush_yds <= 28):
                                        return 36.31818
                    if (pass_yds <= 306):
                        if (rush_yds is None):
                            return 34.34921
                        if (rush_yds > 37):
                            if (comp is None):
                                return 40.33333
                            if (comp > 20):
                                return 42
                            if (comp <= 20):
                                return 38.66667
                        if (rush_yds <= 37):
                            if (pass_yds > 262):
                                if (rush_td is None):
                                    return 35.3
                                if (rush_td > 0):
                                    return 40.5
                                if (rush_td <= 0):
                                    if (rush_yds > 4):
                                        return 35.73333
                                    if (rush_yds <= 4):
                                        return 34
                            if (pass_yds <= 262):
                                if (rush_td is None):
                                    return 31.96296
                                if (rush_td > 0):
                                    return 40
                                if (rush_td <= 0):
                                    if (_int is None):
                                        return 31.65385
                                    if (_int > 0):
                                        return 30.61538
                                    if (_int <= 0):
                                        return 32.69231
            if (pass_td <= 3):
                if (rush_td is None):
                    return 29.38144
                if (rush_td > 0):
                    if (rush_yds is None):
                        return 35.71875
                    if (rush_yds > 48):
                        if (rush_yds > 71):
                            return 41.5
                        if (rush_yds <= 71):
                            return 37.66667
                    if (rush_yds <= 48):
                        if (pass_yds is None):
                            return 35.07407
                        if (pass_yds > 250):
                            return 35.94444
                        if (pass_yds <= 250):
                            if (_int is None):
                                return 33.33333
                            if (_int > 0):
                                return 31.75
                            if (_int <= 0):
                                return 34.6
                if (rush_td <= 0):
                    if (pass_yds is None):
                        return 28.8118
                    if (pass_yds > 325):
                        if (_int is None):
                            return 31.63934
                        if (_int > 1):
                            if (pass_yds > 390):
                                return 31.4
                            if (pass_yds <= 390):
                                if (_int > 3):
                                    return 23
                                if (_int <= 3):
                                    return 27.875
                        if (_int <= 1):
                            if (pass_yds > 388):
                                if (field_2pt_pass is None):
                                    return 34.17857
                                if (field_2pt_pass > 0):
                                    return 39
                                if (field_2pt_pass <= 0):
                                    if (_int > 0):
                                        return 32.66667
                                    if (_int <= 0):
                                        return 34.66667
                            if (pass_yds <= 388):
                                if (rush_yds is None):
                                    return 31.625
                                if (rush_yds > 20):
                                    return 34
                                if (rush_yds <= 20):
                                    if (_int > 0):
                                        if (pass_yds > 373):
                                            return 31.625
                                        if (pass_yds <= 373):
                                            return 29.33333
                                    if (_int <= 0):
                                        if (pass_yds > 349):
                                            return 32.66667
                                        if (pass_yds <= 349):
                                            return 30.94737
                    if (pass_yds <= 325):
                        if (pass_yds > 223):
                            if (_int is None):
                                return 28.07821
                            if (_int > 0):
                                if (rush_yds is None):
                                    return 26.54878
                                if (rush_yds > 60):
                                    return 35.5
                                if (rush_yds <= 60):
                                    if (_int > 1):
                                        if (rush_yds > 24):
                                            return 27.25
                                        if (rush_yds <= 24):
                                            return 24.73077
                                    if (_int <= 1):
                                        if (rush_yds > 9):
                                            return 28.41176
                                        if (rush_yds <= 9):
                                            if (pass_yds > 274):
                                                return 27.3125
                                            if (pass_yds <= 274):
                                                return 25.52941
                            if (_int <= 0):
                                if (rush_yds is None):
                                    return 29.37113
                                if (rush_yds > 29):
                                    if (rush_yds > 46):
                                        return 33.75
                                    if (rush_yds <= 46):
                                        return 31.3
                                if (rush_yds <= 29):
                                    if (pass_yds > 274):
                                        return 30.05405
                                    if (pass_yds <= 274):
                                        if (rush_yds > 17):
                                            return 29.27273
                                        if (rush_yds <= 17):
                                            return 27.62857
                        if (pass_yds <= 223):
                            if (rush_yds is None):
                                return 24.92727
                            if (rush_yds > 20):
                                if (rush_yds > 59):
                                    return 32
                                if (rush_yds <= 59):
                                    return 27.75
                            if (rush_yds <= 20):
                                if (_int is None):
                                    return 24.28261
                                if (_int > 1):
                                    if (pass_yds > 204):
                                        return 23
                                    if (pass_yds <= 204):
                                        return 18.66667
                                if (_int <= 1):
                                    if (pass_yds > 196):
                                        if (_int > 0):
                                            return 23.83333
                                        if (_int <= 0):
                                            return 26.05556
                                    if (pass_yds <= 196):
                                        return 23.70588
        if (pass_td <= 2):
            if (rush_td is None):
                return 21.8361
            if (rush_td > 0):
                if (rush_yds is None):
                    return 29.65432
                if (rush_yds > 82):
                    if (rush_yds > 87):
                        return 38.8
                    if (rush_yds <= 87):
                        return 34.5
                if (rush_yds <= 82):
                    if (pass_yds is None):
                        return 28.90541
                    if (pass_yds > 290):
                        if (_int is None):
                            return 31.91667
                        if (_int > 0):
                            return 29.84615
                        if (_int <= 0):
                            if (rush_yds > 33):
                                return 39.5
                            if (rush_yds <= 33):
                                if (pass_yds > 419):
                                    return 39
                                if (pass_yds <= 419):
                                    return 32.5
                    if (pass_yds <= 290):
                        if (comp is None):
                            return 27.46
                        if (comp > 17):
                            if (rush_yds > 46):
                                return 30.5
                            if (rush_yds <= 46):
                                if (_int is None):
                                    return 27.72414
                                if (_int > 1):
                                    return 25.4
                                if (_int <= 1):
                                    if (pass_yds > 274):
                                        return 30
                                    if (pass_yds <= 274):
                                        return 27.47059
                        if (comp <= 17):
                            if (_int is None):
                                return 25.73333
                            if (_int > 0):
                                return 24
                            if (_int <= 0):
                                return 27.25
            if (rush_td <= 0):
                if (pass_yds is None):
                    return 21.00394
                if (pass_yds > 269):
                    if (_int is None):
                        return 23.03822
                    if (_int > 2):
                        if (pass_yds > 376):
                            return 24
                        if (pass_yds <= 376):
                            if (_int > 3):
                                return 15.66667
                            if (_int <= 3):
                                return 18.5
                    if (_int <= 2):
                        if (_int > 0):
                            if (pass_yds > 300):
                                if (pass_yds > 372):
                                    if (pass_yds > 414):
                                        return 27
                                    if (pass_yds <= 414):
                                        return 24.57143
                                if (pass_yds <= 372):
                                    if (rush_yds is None):
                                        return 22.86735
                                    if (rush_yds > 19):
                                        if (rush_yds > 45):
                                            return 27
                                        if (rush_yds <= 45):
                                            return 24.21429
                                    if (rush_yds <= 19):
                                        if (_int > 1):
                                            if (field_2pt_pass is None):
                                                return 21.31579
                                            if (field_2pt_pass > 0):
                                                return 24
                                            if (field_2pt_pass <= 0):
                                                return 21
                                        if (_int <= 1):
                                            if (pass_yds > 348):
                                                return 23.66667
                                            if (pass_yds <= 348):
                                                return 22.47826
                            if (pass_yds <= 300):
                                if (rush_yds is None):
                                    return 21.06897
                                if (rush_yds > 19):
                                    if (rush_yds > 44):
                                        return 26.66667
                                    if (rush_yds <= 44):
                                        return 22.58333
                                if (rush_yds <= 19):
                                    if (_int > 1):
                                        return 19.21429
                                    if (_int <= 1):
                                        return 20.75862
                        if (_int <= 0):
                            if (pass_yds > 331):
                                if (pass_yds > 426):
                                    return 30.5
                                if (pass_yds <= 426):
                                    if (rush_yds is None):
                                        return 26.375
                                    if (rush_yds > 20):
                                        return 28.5
                                    if (rush_yds <= 20):
                                        return 25.88462
                            if (pass_yds <= 331):
                                if (rush_yds is None):
                                    return 23.89873
                                if (rush_yds > 23):
                                    if (rush_yds > 38):
                                        return 28.33333
                                    if (rush_yds <= 38):
                                        return 25.6
                                if (rush_yds <= 23):
                                    if (pass_yds > 284):
                                        return 23.8
                                    if (pass_yds <= 284):
                                        return 22.66667
                if (pass_yds <= 269):
                    if (_int is None):
                        return 19.57494
                    if (_int > 0):
                        if (rush_yds is None):
                            return 18.25991
                        if (rush_yds > 30):
                            if (_int > 1):
                                return 19.5
                            if (_int <= 1):
                                if (rush_yds > 75):
                                    return 26.33333
                                if (rush_yds <= 75):
                                    if (pass_yds > 250):
                                        return 25
                                    if (pass_yds <= 250):
                                        return 21.88889
                        if (rush_yds <= 30):
                            if (pass_yds > 215):
                                if (_int > 2):
                                    if (_int > 3):
                                        return 11
                                    if (_int <= 3):
                                        return 15.42857
                                if (_int <= 2):
                                    if (rush_yds > 10):
                                        if (_int > 1):
                                            return 19.07692
                                        if (_int <= 1):
                                            return 20.71429
                                    if (rush_yds <= 10):
                                        if (_int > 1):
                                            return 17.47826
                                        if (_int <= 1):
                                            return 18.91525
                            if (pass_yds <= 215):
                                if (_int > 1):
                                    if (pass_yds > 142):
                                        return 15.52
                                    if (pass_yds <= 142):
                                        return 12
                                if (_int <= 1):
                                    if (pass_yds > 173):
                                        return 17.73684
                                    if (pass_yds <= 173):
                                        return 15.6
                    if (_int <= 0):
                        if (pass_yds > 199):
                            if (rush_yds is None):
                                return 21.81879
                            if (rush_yds > 33):
                                if (rush_yds > 71):
                                    return 30
                                if (rush_yds <= 71):
                                    return 24.46667
                            if (rush_yds <= 33):
                                if (rush_yds > 19):
                                    return 22.76471
                                if (rush_yds <= 19):
                                    if (pass_yds > 248):
                                        return 21.95238
                                    if (pass_yds <= 248):
                                        if (rush_yds > 8):
                                            return 21.43333
                                        if (rush_yds <= 8):
                                            return 20.5
                        if (pass_yds <= 199):
                            if (rush_yds is None):
                                return 19.07042
                            if (rush_yds > 30):
                                if (rush_yds > 59):
                                    return 25
                                if (rush_yds <= 59):
                                    return 20.81818
                            if (rush_yds <= 30):
                                if (pass_yds > 166):
                                    if (rush_yds > 11):
                                        return 20.36364
                                    if (rush_yds <= 11):
                                        return 18.52632
                                if (pass_yds <= 166):
                                    return 17.55556
    if (pass_td <= 1):
        if (pass_td > 0):
            if (rush_td is None):
                return 14.30098
            if (rush_td > 0):
                if (rush_td > 1):
                    if (rush_yds is None):
                        return 31.66667
                    if (rush_yds > 87):
                        return 38.5
                    if (rush_yds <= 87):
                        if (rush_yds > 3):
                            return 30.33333
                        if (rush_yds <= 3):
                            return 26
                if (rush_td <= 1):
                    if (rush_yds is None):
                        return 21.5
                    if (rush_yds > 40):
                        if (pass_yds is None):
                            return 24.25926
                        if (pass_yds > 248):
                            return 26.75
                        if (pass_yds <= 248):
                            if (rush_yds > 113):
                                return 30
                            if (rush_yds <= 113):
                                if (_int is None):
                                    return 22.83333
                                if (_int > 1):
                                    return 20.75
                                if (_int <= 1):
                                    if (pass_yds > 195):
                                        return 24.33333
                                    if (pass_yds <= 195):
                                        return 21.8
                    if (rush_yds <= 40):
                        if (pass_yds is None):
                            return 20.60241
                        if (pass_yds > 279):
                            if (pass_yds > 440):
                                return 27
                            if (pass_yds <= 440):
                                return 22.28
                        if (pass_yds <= 279):
                            if (rush_yds > 21):
                                return 21.09524
                            if (rush_yds <= 21):
                                if (pass_yds > 225):
                                    if (_int is None):
                                        return 20.26667
                                    if (_int > 0):
                                        return 19.5
                                    if (_int <= 0):
                                        return 21.8
                                if (pass_yds <= 225):
                                    if (_int is None):
                                        return 17.6
                                    if (_int > 0):
                                        return 16.4
                                    if (_int <= 0):
                                        if (pass_yds > 146):
                                            return 20
                                        if (pass_yds <= 146):
                                            return 17
            if (rush_td <= 0):
                if (pass_yds is None):
                    return 13.35657
                if (pass_yds > 198):
                    if (_int is None):
                        return 14.88308
                    if (_int > 1):
                        if (pass_yds > 311):
                            if (pass_yds > 426):
                                return 21.5
                            if (pass_yds <= 426):
                                if (pass_yds > 374):
                                    return 17.2
                                if (pass_yds <= 374):
                                    return 14.82609
                        if (pass_yds <= 311):
                            if (rush_yds is None):
                                return 11.24779
                            if (rush_yds > 31):
                                if (rush_yds > 81):
                                    return 19.5
                                if (rush_yds <= 81):
                                    if (pass_yds > 255):
                                        return 16
                                    if (pass_yds <= 255):
                                        return 13
                            if (rush_yds <= 31):
                                if (pass_yds > 249):
                                    if (_int > 2):
                                        if (_int > 3):
                                            return 8.6
                                        if (_int <= 3):
                                            return 11
                                    if (_int <= 2):
                                        return 12.88889
                                if (pass_yds <= 249):
                                    if (_int > 2):
                                        if (_int > 3):
                                            return 6.33333
                                        if (_int <= 3):
                                            return 9.06667
                                    if (_int <= 2):
                                        if (rush_yds > 14):
                                            return 12.4
                                        if (rush_yds <= 14):
                                            return 10.21212
                    if (_int <= 1):
                        if (pass_yds > 264):
                            if (pass_yds > 315):
                                if (field_2pt_pass is None):
                                    return 18.5
                                if (field_2pt_pass > 0):
                                    return 21.75
                                if (field_2pt_pass <= 0):
                                    if (_int > 0):
                                        if (rush_yds is None):
                                            return 17.67647
                                        if (rush_yds > 13):
                                            return 19.14286
                                        if (rush_yds <= 13):
                                            return 17.2963
                                    if (_int <= 0):
                                        if (pass_yds > 324):
                                            if (pass_yds > 326):
                                                return 19.41176
                                            if (pass_yds <= 326):
                                                return 27
                                        if (pass_yds <= 324):
                                            return 17.75
                            if (pass_yds <= 315):
                                if (rush_yds is None):
                                    return 16.62963
                                if (rush_yds > 16):
                                    return 18.74074
                                if (rush_yds <= 16):
                                    if (_int > 0):
                                        return 15.02041
                                    if (_int <= 0):
                                        if (pass_yds > 274):
                                            if (field_2pt_pass is None):
                                                return 17.42857
                                            if (field_2pt_pass > 0):
                                                return 19.66667
                                            if (field_2pt_pass <= 0):
                                                return 17.25641
                                        if (pass_yds <= 274):
                                            return 15.94118
                        if (pass_yds <= 264):
                            if (rush_yds is None):
                                return 14.57237
                            if (rush_yds > 19):
                                if (rush_yds > 39):
                                    if (_int > 0):
                                        return 17.14286
                                    if (_int <= 0):
                                        return 19.8
                                if (rush_yds <= 39):
                                    if (_int > 0):
                                        if (pass_yds > 242):
                                            return 16.2
                                        if (pass_yds <= 242):
                                            return 14.41176
                                    if (_int <= 0):
                                        return 16.96296
                            if (rush_yds <= 19):
                                if (_int > 0):
                                    if (pass_yds > 235):
                                        if (field_2pt_pass is None):
                                            return 13.61818
                                        if (field_2pt_pass > 0):
                                            return 15.75
                                        if (field_2pt_pass <= 0):
                                            return 13.45098
                                    if (pass_yds <= 235):
                                        if (rush_yds > 9):
                                            return 13.4
                                        if (rush_yds <= 9):
                                            return 11.93333
                                if (_int <= 0):
                                    if (pass_yds > 223):
                                        return 15.38571
                                    if (pass_yds <= 223):
                                        return 14.22917
                if (pass_yds <= 198):
                    if (rush_yds is None):
                        return 10.55367
                    if (rush_yds > 20):
                        if (rush_yds > 40):
                            if (_int is None):
                                return 16
                            if (_int > 0):
                                return 14.625
                            if (_int <= 0):
                                if (rush_yds > 63):
                                    return 19
                                if (rush_yds <= 63):
                                    return 16.2
                        if (rush_yds <= 40):
                            if (_int is None):
                                return 12.67273
                            if (_int > 1):
                                return 10.09091
                            if (_int <= 1):
                                if (comp is None):
                                    return 13.31818
                                if (comp > 13):
                                    return 13.83871
                                if (comp <= 13):
                                    return 12.07692
                    if (rush_yds <= 20):
                        if (_int is None):
                            return 9.72302
                        if (_int > 1):
                            if (pass_yds > 160):
                                if (rush_yds > 10):
                                    return 10.16667
                                if (rush_yds <= 10):
                                    return 8.20833
                            if (pass_yds <= 160):
                                if (_int > 2):
                                    return 4
                                if (_int <= 2):
                                    if (pass_yds > 100):
                                        return 6.86667
                                    if (pass_yds <= 100):
                                        return 4.5
                        if (_int <= 1):
                            if (pass_yds > 149):
                                if (_int > 0):
                                    if (rush_yds > 8):
                                        return 11.4375
                                    if (rush_yds <= 8):
                                        return 10.23077
                                if (_int <= 0):
                                    return 12.86538
                            if (pass_yds <= 149):
                                if (pass_yds > 74):
                                    if (_int > 0):
                                        if (pass_yds > 121):
                                            return 9.2
                                        if (pass_yds <= 121):
                                            return 7.75
                                    if (_int <= 0):
                                        return 10.19231
                                if (pass_yds <= 74):
                                    return 7.67742
        if (pass_td <= 0):
            if (pass_yds is None):
                return 4.46512
            if (pass_yds > 124):
                if (rush_td is None):
                    return 7.98835
                if (rush_td > 0):
                    if (_int is None):
                        return 15.04819
                    if (_int > 1):
                        if (rush_yds is None):
                            return 11.05882
                        if (rush_yds > 69):
                            return 18
                        if (rush_yds <= 69):
                            if (att is None):
                                return 10.625
                            if (att > 45):
                                return 16
                            if (att <= 45):
                                if (pass_yds > 173):
                                    return 10.76923
                                if (pass_yds <= 173):
                                    return 7
                    if (_int <= 1):
                        if (pass_yds > 221):
                            if (rush_yds is None):
                                return 18.03846
                            if (rush_yds > 33):
                                return 21.2
                            if (rush_yds <= 33):
                                if (rush_yds > 8):
                                    if (field_2pt_pass is None):
                                        return 17.82353
                                    if (field_2pt_pass > 0):
                                        return 22
                                    if (field_2pt_pass <= 0):
                                        return 17.5625
                                if (rush_yds <= 8):
                                    return 15
                        if (pass_yds <= 221):
                            if (rush_yds is None):
                                return 14.8
                            if (rush_yds > 43):
                                if (rush_td > 1):
                                    return 22
                                if (rush_td <= 1):
                                    return 16.92308
                            if (rush_yds <= 43):
                                if (rush_td > 1):
                                    return 18
                                if (rush_td <= 1):
                                    if (rush_yds > 16):
                                        return 13.93333
                                    if (rush_yds <= 16):
                                        if (pass_yds > 177):
                                            return 13.66667
                                        if (pass_yds <= 177):
                                            return 10.66667
                if (rush_td <= 0):
                    if (_int is None):
                        return 6.63194
                    if (_int > 1):
                        if (pass_yds > 248):
                            if (rush_yds is None):
                                return 6.36364
                            if (rush_yds > 31):
                                return 13.5
                            if (rush_yds <= 31):
                                if (_int > 3):
                                    return 2.66667
                                if (_int <= 3):
                                    if (pass_yds > 284):
                                        return 7.72727
                                    if (pass_yds <= 284):
                                        return 5.85714
                        if (pass_yds <= 248):
                            if (_int > 2):
                                if (_int > 3):
                                    return -2.25
                                if (_int <= 3):
                                    if (comp is None):
                                        return 1.8
                                    if (comp > 12):
                                        if (pass_yds > 136):
                                            return 1.94118
                                        if (pass_yds <= 136):
                                            return 6
                                    if (comp <= 12):
                                        return -1.5
                            if (_int <= 2):
                                if (rush_yds is None):
                                    return 3.78462
                                if (rush_yds > 16):
                                    if (rush_yds > 49):
                                        return 8.66667
                                    if (rush_yds <= 49):
                                        return 5.3
                                if (rush_yds <= 16):
                                    if (pass_yds > 174):
                                        return 3.90625
                                    if (pass_yds <= 174):
                                        if (att is None):
                                            return 2.1
                                        if (att > 16):
                                            return 1.89474
                                        if (att <= 16):
                                            return 6
                    if (_int <= 1):
                        if (pass_yds > 242):
                            if (pass_yds > 323):
                                if (pass_yds > 377):
                                    return 16.33333
                                if (pass_yds <= 377):
                                    return 12.75
                            if (pass_yds <= 323):
                                if (rush_yds is None):
                                    return 10.21739
                                if (rush_yds > 30):
                                    return 13.14286
                                if (rush_yds <= 30):
                                    if (field_2pt_pass is None):
                                        return 9.8871
                                    if (field_2pt_pass > 0):
                                        if (att is None):
                                            return 12.75
                                        if (att > 38):
                                            return 20
                                        if (att <= 38):
                                            return 10.33333
                                    if (field_2pt_pass <= 0):
                                        if (_int > 0):
                                            return 8.90625
                                        if (_int <= 0):
                                            if (pass_yds > 275):
                                                return 11.75
                                            if (pass_yds <= 275):
                                                return 9.71429
                        if (pass_yds <= 242):
                            if (rush_yds is None):
                                return 6.63478
                            if (rush_yds > 25):
                                if (pass_yds > 207):
                                    return 12.8
                                if (pass_yds <= 207):
                                    if (rush_yds > 88):
                                        return 13
                                    if (rush_yds <= 88):
                                        return 8.71429
                            if (rush_yds <= 25):
                                if (pass_yds > 201):
                                    if (_int > 0):
                                        return 6.5641
                                    if (_int <= 0):
                                        return 8.72727
                                if (pass_yds <= 201):
                                    if (_int > 0):
                                        if (pass_yds > 167):
                                            if (rush_yds > 2):
                                                return 6
                                            if (rush_yds <= 2):
                                                return 4.68421
                                        if (pass_yds <= 167):
                                            return 3.35714
                                    if (_int <= 0):
                                        if (pass_yds > 174):
                                            return 7.05
                                        if (pass_yds <= 174):
                                            return 5.86486
            if (pass_yds <= 124):
                if (rush_td is None):
                    return 0.95551
                if (rush_td > 0):
                    if (rush_yds is None):
                        return 10.94737
                    if (rush_yds > 47):
                        if (pass_yds > 44):
                            return 15.33333
                        if (pass_yds <= 44):
                            return 11
                    if (rush_yds <= 47):
                        if (pass_yds > 77):
                            return 10.42857
                        if (pass_yds <= 77):
                            return 6.4
                if (rush_td <= 0):
                    if (pass_yds > 75):
                        if (_int is None):
                            return 2.47368
                        if (_int > 1):
                            if (_int > 2):
                                return -2.6
                            if (_int <= 2):
                                return -0.33333
                        if (_int <= 1):
                            if (rush_yds is None):
                                return 3.23077
                            if (rush_yds > 30):
                                if (rush_yds > 52):
                                    return 9.25
                                if (rush_yds <= 52):
                                    return 6
                            if (rush_yds <= 30):
                                if (_int > 0):
                                    return 1.88571
                                if (_int <= 0):
                                    return 3.57143
                    if (pass_yds <= 75):
                        if (_int is None):
                            return 0.12655
                        if (_int > 1):
                            if (_int > 2):
                                return -7
                            if (_int <= 2):
                                return -2.77778
                        if (_int <= 1):
                            if (pass_yds > 24):
                                if (_int > 0):
                                    if (rush_yds is None):
                                        return -0.11111
                                    if (rush_yds > 18):
                                        return 1.8
                                    if (rush_yds <= 18):
                                        return -0.54545
                                if (_int <= 0):
                                    return 1.36145
                            if (pass_yds <= 24):
                                if (_int > 0):
                                    return -1.78261
                                if (_int <= 0):
                                    if (rush_yds is None):
                                        return 0.13619
                                    if (rush_yds > 9):
                                        return 1.5
                                    if (rush_yds <= 9):
                                        return 0.04564


def main():
    value = predict_score(30, 21, 300, 3, 0, 0, 0, 0);
    print("att: 30, comp: 21, pyards: 300, ptds: 3")
    print(value);


if __name__ == "__main__":
    main()
# Out:
# att: 30, comp: 21, pyards: 300, ptds: 3
# 30.05405
